# %%
import os
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
os.chdir('/content/drive/My Drive/Colab Notebooks')
os.listdir()
# Out:
# ['coding', 'Untitled0.ipynb', 'data1.csv']

# %%
import pandas as pd
data1 = pd.read_csv("data1.csv")
data2 = pd.read_csv("data2.csv")

# %%
data1
# Out:
#            Name                            Date         Subs   完成    時長 課程形式
# 0    李冠郁_Thomas  2023/02/05 10:30 AM → 12:00 PM   國一, 翰林, 英文  Yes  90.0  PS1
# 1   李冠郁_Thomas   2023/02/19 10:30 AM → 12:00 PM  國一, 總複習, 英文  Yes  90.0  PS1
# 2   李冠郁_Thomas   2023/02/26 10:30 AM → 12:00 PM  國一, 總複習, 英文  Yes  90.0  PS1
# 3   李冠郁_Thomas   2023/02/12 10:30 AM → 12:00 PM  國一, 總複習, 英文  Yes  90.0  PS1
# 4           NaN                             NaN          NaN  NaN   NaN  NaN
# 5           羅英綺    2023/02/05 6:00 PM → 7:30 PM   英文, 高二, 龍騰  Yes  90.0  PS1
# 6           NaN                             NaN          NaN  NaN   NaN  NaN
# 7       鈺淮_Josh    2023/02/20 6:00 PM → 7:30 PM  小學, 總複習, 英文  Yes  90.0  PS1
# 8       鈺淮_Josh    2023/02/09 4:40 PM → 6:10 PM  小學, 總複習, 英文  Yes  90.0  PS1
# 9       鈺淮_Josh    2023/02/13 6:00 PM → 7:30 PM  小學, 總複習, 英文  Yes  90.0  PS1
# 10          NaN                             NaN          NaN  NaN   NaN  NaN
# 11     黃學承_Matt  2023/02/07 11:00 AM → 12:00 PM   小學, 翰林, 英文  Yes  60.0  PS1
# 12     黃學承_Matt    2023/02/12 5:00 PM → 6:00 PM   小學, 翰林, 英文  Yes  60.0  PS1
# 13   黃紫薰_Selina    2023/02/12 4:00 PM → 5:00 PM   小學, 康軒, 英文  Yes  60.0  PS1
# 14   黃紫薰_Selina   2023/02/07 12:00 PM → 1:00 PM   小學, 康軒, 英文  Yes  60.0  PS1
# 15          NaN                             NaN          NaN  NaN   NaN  NaN
# 16          NaN                             NaN          NaN  NaN  16.0   小時

# %%
data2
# Out:
#           Name  類型                            Date         Subs 學生來源   完成  時長  \
# 0    曼真(Joyce) NaN    2022/11/24 7:30 PM → 8:30 PM   英文, 高二, 龍騰   高洋  Yes  60
# 1    曼真(Joyce) NaN    2022/11/10 7:30 PM → 8:30 PM   英文, 高二, 龍騰   高洋  Yes  60
# 2    曼真(Joyce) NaN    2022/11/21 7:30 PM → 8:30 PM   英文, 高二, 龍騰   高洋  Yes  60
# 3    曼真(Joyce) NaN    2022/11/04 2:00 PM → 3:00 PM   英文, 高二, 龍騰   高洋  Yes  60
# 4    曼真(Joyce) NaN    2022/11/07 7:30 PM → 8:30 PM   英文, 高二, 龍騰   高洋  Yes  60
# 5   李冠郁_Thomas NaN  2022/11/13 10:30 AM → 12:00 PM  國三, 總複習, 英文   高洋  Yes  90
# 6   李冠郁_Thomas NaN  2022/11/20 10:30 AM → 12:00 PM  國三, 總複習, 英文   高洋  Yes  90
# 7   李冠郁_Thomas NaN  2022/11/06 10:30 AM → 12:00 PM  國三, 總複習, 英文   高洋  Yes  90
# 8   李冠郁_Thomas NaN  2022/11/27 10:30 AM → 12:00 PM  國三, 總複習, 英文   高洋  Yes  90
# 9          羅英綺 NaN   2022/11/27 8:30 PM → 10:00 PM   英文, 高二, 龍騰   高洋  Yes  90
# 10         羅英綺 NaN    2022/11/29 5:00 PM → 6:30 PM   英文, 高二, 龍騰   高洋  Yes  90
# 11         羅英綺 NaN    2022/11/13 7:00 PM → 8:30 PM   英文, 高二, 龍騰   高洋  Yes  90
# 12     鈺淮_Josh NaN    2022/11/21 7:00 PM → 8:30 PM  國三, 總複習, 英文   高洋  Yes  90
# 13     鈺淮_Josh NaN    2022/11/24 7:00 PM → 8:30 PM  國三, 總複習, 英文   高洋  Yes  90
# 14     鈺淮_Josh NaN    2022/11/28 7:00 PM → 8:30 PM  國三, 總複習, 英文   高洋  Yes  90
# 15     鈺淮_Josh NaN    2022/11/07 7:00 PM → 8:30 PM  國三, 總複習, 英文   高洋  Yes  90
# 16    黃學承_Matt NaN    2022/11/27 8:30 PM → 9:30 PM   小學, 翰林, 英文   高洋  Yes  60
# 17    黃學承_Matt NaN    2022/11/13 8:30 PM → 9:30 PM   小學, 翰林, 英文   高洋  Yes  60
# 18    黃學承_Matt NaN    2022/11/06 8:30 PM → 9:30 PM   小學, 翰林, 英文   高洋  Yes  60
# 19    黃學承_Matt NaN    2022/11/20 8:30 PM → 9:30 PM   小學, 翰林, 英文   高洋  Yes  60
# 20  黃紫薰_Selina NaN    2022/11/24 8:30 PM → 9:30 PM   小學, 康軒, 英文   高洋  Yes  60
# 21  黃紫薰_Selina NaN    2022/11/17 8:30 PM → 9:30 PM   小學, 康軒, 英文   高洋  Yes  60
# 22  黃紫薰_Selina NaN    2022/11/10 8:30 PM → 9:30 PM   小學, 康軒, 英文   高洋  Yes  60
# 23  黃紫薰_Selina NaN    2022/11/03 8:30 PM → 9:30 PM   小學, 康軒, 英文   高洋  Yes  60
#
#    課程形式
# 0   PS1
# 1   PS1
# 2   PS1
# 3   PS1
# 4   PS1
# 5   PS1
# 6   PS1
# 7   PS1
# 8   PS1
# 9   PS1
# 10  PS1
# 11  PS1
# 12  PS1
# 13  PS1
# 14  PS1
# 15  PS1
# 16  PS1
# 17  PS1
# 18  PS1
# 19  PS1
# 20  PS1
# 21  PS1
# 22  PS1
# 23  PS1

# %%
set_data1 = set(data1["Name"])
set_data2 = set(data2["Name"])

# %%
set_data2
# Out:
# {'曼真(Joyce)', '李冠郁_Thomas', '羅英綺', '鈺淮_Josh', '黃學承_Matt', '黃紫薰_Selina'}

# %%
set_data1
# Out:
# {nan, '李冠郁_Thomas', '李冠郁_Thomas ', '羅英綺', '鈺淮_Josh', '黃學承_Matt', '黃紫薰_Selina'}

# %%
聯集 = set_data1 | set_data2
聯集
# Out:
# {nan,
#  '曼真(Joyce)',
#  '李冠郁_Thomas',
#  '李冠郁_Thomas ',
#  '羅英綺',
#  '鈺淮_Josh',
#  '黃學承_Matt',
#  '黃紫薰_Selina'}

# %%
交集 = set_data1 & set_data2
交集
# Out:
# {'李冠郁_Thomas', '羅英綺', '鈺淮_Josh', '黃學承_Matt', '黃紫薰_Selina'}

# %%
差集 = set_data1 - 交集
差集
# Out:
# {nan, '李冠郁_Thomas '}

# %%
對稱差集 = 聯集 - 交集
對稱差集
# Out:
# {nan, '曼真(Joyce)', '李冠郁_Thomas '}
